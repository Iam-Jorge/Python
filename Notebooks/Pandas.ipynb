# %% [markdown]
# ## Pandas

# %% [markdown]
# Pandas es una biblioteca de código abierto de Python que proporciona una colección de herramientas de análisis de datos para trabajar con conjuntos de datos. Para instalarlo pip install pandas.
#
# - Pandas proporciona una forma eficiente de explorar datos.
# - Tiene características que ayudan en el manejo de datos que faltan.
# - Soporta múltiples formatos de archivo como CSV, JSON, Excel, etc.
# - Puede fusionar de manera eficiente una variedad de conjuntos de datos para el análisis de datos sin problemas.
# - Proporciona herramientas para leer y escribir datos durante el análisis.

# %% [markdown]
# ### Creación, lectura y escritura

# %% [markdown]
# Tenemos dos estructuras de datos principales
# - Series: Es un array unidimensional etiquetada que podemos ver como una columna de una hoja excel
# - DataFrame: Es un array bidimensional y se representa mayoritariamente como una tabla.

# %% [markdown]
# #### Creación Serie (Columna)

# %%
import pandas as pd

ingredients = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index = ['Flour', 'Milk', 'Eggs', 'Spam'], name = 'Dinner')
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %% [markdown]
# #### Creación Dataframe (Tabla)

# %%
fruit_sales = pd.DataFrame([[35, 21],[41, 34]], columns=['Apples', 'Bananas'], index = ['2017 Sales', '2018 Sales'])
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# #### Lectura de ficheros (CSV)

# %%
reviews = pd.read_csv('../data/Others/wine-reviews.csv', index_col=0)
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]

# %% [markdown]
# #### Guardar ficheros (CSV)

# %%
reviews.to_csv("../data/Others/wine-reviews2.csv")

# %% [markdown]
# ### Selección, indexación y acceso

# %% [markdown]
# #### Seleccionar una columna (Serie)

# %%
reviews = pd.read_csv('../data/Others/wine-reviews.csv', index_col=0)
reviews.description
# Out:
# 0         This tremendous 100% varietal wine hails from ...
# 1         Ripe aromas of fig, blackberry and cassis are ...
# 2         Mac Watson honors the memory of a wine once ma...
# 3         This spent 20 months in 30% new French oak, an...
# 4         This is the top wine from La Bégude, named aft...
#                                 ...
# 150925    Many people feel Fiano represents southern Ita...
# 150926    Offers an intriguing nose with ginger, lime an...
# 150927    This classic example comes from a cru vineyard...
# 150928    A perfect salmon shade, with scents of peaches...
# 150929    More Pinot Grigios should taste like this. A r...
# Name: description, Length: 150930, dtype: object

# %% [markdown]
# #### Seleccionar elementos de una fila

# %%
# Se selecciona el primer elemento de la primera fila
first_description = reviews.description[0]
first_description
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %% [markdown]
# #### Seleccionar una fila

# %%
first_row = reviews.iloc[0]
first_row
# Out:
# country                                                       US
# description    This tremendous 100% varietal wine hails from ...
# designation                                    Martha's Vineyard
# points                                                        96
# price                                                      235.0
# province                                              California
# region_1                                             Napa Valley
# region_2                                                    Napa
# variety                                       Cabernet Sauvignon
# winery                                                     Heitz
# Name: 0, dtype: object

# %% [markdown]
# #### Seleccionar los n primeros resultados de una columna

# %%
first_descriptions = reviews.description[:3]
first_descriptions
# Out:
# 0    This tremendous 100% varietal wine hails from ...
# 1    Ripe aromas of fig, blackberry and cassis are ...
# 2    Mac Watson honors the memory of a wine once ma...
# Name: description, dtype: object

# %% [markdown]
# #### Seleccionar registro con indices

# %%
indices = [1, 2, 5, 8]
sample_reviews = reviews.loc[indices]
sample_reviews
# Out:
#   country                                        description  \
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 8      US  This re-named vineyard was formerly bottled as...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 5                             Numanthia      95   73.0  Northern Spain
# 8                                Silice      95   65.0          Oregon
#
#              region_1           region_2          variety  \
# 1                Toro                NaN    Tinta de Toro
# 2      Knights Valley             Sonoma  Sauvignon Blanc
# 5                Toro                NaN    Tinta de Toro
# 8  Chehalem Mountains  Willamette Valley       Pinot Noir
#
#                     winery
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 5                Numanthia
# 8                Bergström

# %% [markdown]
# #### Selección de columnas

# %%
cols = ['country', 'province', 'region_1', 'region_2']
indices = [0, 1, 10, 100]
df = reviews.loc[indices, cols]
df
# Out:
#     country            province     region_1     region_2
# 0        US          California  Napa Valley         Napa
# 1     Spain      Northern Spain         Toro          NaN
# 10    Italy  Northeastern Italy       Collio          NaN
# 100      US          California  South Coast  South Coast

# %% [markdown]
# #### Selección con criterio por columna

# %%
spanish_wines = reviews[reviews.country == 'Spain']
spanish_wines
# Out:
#        country                                        description  \
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 5        Spain  Deep, dense and pure from the opening bell, th...
# 6        Spain  Slightly gritty black-fruit aromas include a s...
# 7        Spain  Lush cedary black-fruit aromas are luxe and of...
# 17       Spain  Nicely oaked blackberry, licorice, vanilla and...
# ...        ...                                                ...
# 149601   Spain  Toasty oak and tobacco shadings are wrapped ar...
# 149819   Spain  This pleasant wine shows clean apple, hay and ...
# 149858   Spain  Dried cherry and spice aromas and flavors acce...
# 149936   Spain  A straightforward basic red, with dried cherry...
# 149993   Spain  This Rioja rose displays a full bouquet of ros...
#
#                                  designation  points  price        province  \
# 1       Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 5                                  Numanthia      95   73.0  Northern Spain
# 6                                  San Román      95   65.0  Northern Spain
# 7                    Carodorum Único Crianza      95  110.0  Northern Spain
# 17                    6 Años Reserva Premium      95   80.0  Northern Spain
# ...                                      ...     ...    ...             ...
# 149601                         Rioja Crianza      88   15.0  Northern Spain
# 149819                                   NaN      86    7.0   Central Spain
# 149858                          Faustino VII      86   12.0  Northern Spain
# 149936                                   NaN      84    7.0  Northern Spain
# 149993                     Faustino V Rosado      84   12.0  Northern Spain
#
#                 region_1 region_2            variety                   winery
# 1                   Toro      NaN      Tinta de Toro  Bodega Carmen Rodríguez
# 5                   Toro      NaN      Tinta de Toro                Numanthia
# 6                   Toro      NaN      Tinta de Toro                 Maurodos
# 7                   Toro      NaN      Tinta de Toro  Bodega Carmen Rodríguez
# 17      Ribera del Duero      NaN        Tempranillo                 Valduero
# ...                  ...      ...                ...                      ...
# 149601             Rioja      NaN  Tempranillo Blend         Bodegas Faustino
# 149819  Tierra Manchuela      NaN              Viura                  Santana
# 149858             Rioja      NaN        Tempranillo         Bodegas Faustino
# 149936             Rioja      NaN        Tempranillo                  Santana
# 149993             Rioja      NaN               Rosé         Bodegas Faustino
#
# [8268 rows x 10 columns]

# %% [markdown]
# #### Selección con varios criterio de búsqueda

# %%
top_oceania_wines = reviews.loc[
    (reviews.country.isin(['Australia', 'New Zealand']))
    & (reviews.points >= 95)
]
top_oceania_wines
# Out:
#           country                                        description  \
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458    Australia  This is a top example of the classic Australia...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 3044    Australia  From vines planted in 1912, this has been an i...
# 3047    Australia  This is a throwback to those brash, flavor-exu...
# ...           ...                                                ...
# 122779  Australia  If Standish's Relic is the feminine side of Sh...
# 127614  Australia  This stellar wine takes a little time in the g...
# 137383  Australia  The 2007 Astralis impresses for its combinatio...
# 150562  Australia  As unevolved as they are, the dense and multil...
# 150563  Australia  Seamless luxury from stem to stern, this ‘baby...
#
#                          designation  points  price         province  \
# 2148                      The Factor      98  125.0  South Australia
# 2458                       The Peake      96  150.0  South Australia
# 3033                         Bin 707      95  500.0  South Australia
# 3044        Mount Edelstone Vineyard      95  200.0  South Australia
# 3047                             One      95   95.0  South Australia
# ...                              ...     ...    ...              ...
# 122779  The Standish Single Vineyard      96  135.0  South Australia
# 127614                 Hill of Grace      95  625.0  South Australia
# 137383                      Astralis      95  225.0  South Australia
# 150562                        Grange      96  185.0  South Australia
# 150563                           RWT      95   70.0  South Australia
#
#                region_1 region_2             variety           winery
# 2148     Barossa Valley      NaN              Shiraz         Torbreck
# 2458       McLaren Vale      NaN     Cabernet-Shiraz     Hickinbotham
# 3033    South Australia      NaN  Cabernet Sauvignon         Penfolds
# 3044        Eden Valley      NaN              Shiraz         Henschke
# 3047    Langhorne Creek      NaN           Red Blend        Heartland
# ...                 ...      ...                 ...              ...
# 122779   Barossa Valley      NaN              Shiraz         Standish
# 127614      Eden Valley      NaN              Shiraz         Henschke
# 137383        Clarendon      NaN               Syrah  Clarendon Hills
# 150562  South Australia      NaN              Shiraz         Penfolds
# 150563   Barossa Valley      NaN              Shiraz         Penfolds
#
# [82 rows x 10 columns]

# %% [markdown]
# #### Selección el mejor resultado según un criterio

# %%
reviews = pd.read_csv('../data/Others/wine-reviews.csv', index_col=0)
bargain_idx = (reviews.points / reviews.price).idxmax()
bargain_wine = reviews.loc[bargain_idx]
bargain_wine
# Out:
# country                                                       US
# description    There's a lot going on in this Merlot, which i...
# designation                                                  NaN
# points                                                        86
# price                                                        4.0
# province                                              California
# region_1                                              California
# region_2                                        California Other
# variety                                                   Merlot
# winery                                                    Bandit
# Name: 25645, dtype: object

# %% [markdown]
# #### Selección y búsqueda

# %%
n_trop = reviews.description.map(lambda desc: "tropical" in desc).sum()
n_fruity = reviews.description.map(lambda desc: "fruity" in desc).sum()
descriptor_counts = pd.Series([n_trop, n_fruity], index=['tropical', 'fruity'])
descriptor_counts
# Out:
# tropical    4135
# fruity      8669
# dtype: int64

# %% [markdown]
# ### Estadística descriptiva

# %% [markdown]
# Pandas proporciona muchas "funciones de resumen" que permiten reestructuran los datos de alguna manera útil.

# %% [markdown]
# ##### Mean

# %%
mean_price = reviews.price.mean()
print('Precio medio:', mean_price)
# Out:
# Precio medio: 33.13148249353299

# %% [markdown]
# ##### Función describe

# %%
# Proporciona varias estadísticas descriptivas general de los datos
reviews.points.describe()
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %%
# También sirve para datos no numericos
reviews.country.describe()
# Out:
# count     150925
# unique        48
# top           US
# freq       62397
# Name: country, dtype: object

# %%
# Valores únicos
reviews_per_country = reviews.country.unique()
reviews_per_country
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %% [markdown]
# ### Funciones de mapeado

# %% [markdown]
# A menudo necesitamos crear nuevas representaciones a partir de datos existentes, o transformar datos del formato actual al formato que queremos que tengan más adelante. Los mapas son los que se encargan de este trabajo, por lo que son extremadamente importantes para llevarlo a cabo.

# %%
# Se le suma 10 al precio de cada vino
def fun1(x):
    return x + 10
reviews.price = reviews.price.map(lambda x:fun1(x))
reviews.price
# Out:
# 0         245.0
# 1         120.0
# 2         100.0
# 3          75.0
# 4          76.0
#           ...
# 150925     30.0
# 150926     37.0
# 150927     30.0
# 150928     62.0
# 150929     25.0
# Name: price, Length: 150930, dtype: float64

# %%
# Otra forma de hacerlo sustraemos el precio medio del precio actual
centered_price = reviews.price - reviews.price.mean()
centered_price.head(3)
# Out:
# 0    201.868518
# 1     76.868518
# 2     56.868518
# Name: price, dtype: float64

# %% [markdown]
# Transoformamos el sistema de puntuación (0-100) a puntuación uno más sencillo que se basado en estrellas

# %%
def stars(row):
    if row.country == 'Canada':
        return 3
    elif row.points >= 95:
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1

star_ratings = reviews.apply(stars, axis='columns')
star_ratings
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 150925    2
# 150926    2
# 150927    2
# 150928    2
# 150929    2
# Length: 150930, dtype: int64

# %% [markdown]
# ### Agrupación y Ordenación

# %%
reviews = pd.read_csv('../data/Others/wine-reviews.csv', index_col=0)
reviews.description

# Agrupamos las reviews por pais
reviews_per_country = reviews.country.value_counts()
reviews_per_country
# Out:
# country
# US                        62397
# Italy                     23478
# France                    21098
# Spain                      8268
# Chile                      5816
# Argentina                  5631
# Portugal                   5322
# Australia                  4957
# New Zealand                3320
# Austria                    3057
# Germany                    2452
# South Africa               2258
# Greece                      884
# Israel                      630
# Hungary                     231
# Canada                      196
# Romania                     139
# Slovenia                     94
# Uruguay                      92
# Croatia                      89
# Bulgaria                     77
# Moldova                      71
# Mexico                       63
# Turkey                       52
# Georgia                      43
# Lebanon                      37
# Cyprus                       31
# Brazil                       25
# Macedonia                    16
# Serbia                       14
# Morocco                      12
# England                       9
# Luxembourg                    9
# Lithuania                     8
# India                         8
# Czech Republic                6
# Ukraine                       5
# Switzerland                   4
# South Korea                   4
# Bosnia and Herzegovina        4
# China                         3
# Egypt                         3
# Slovakia                      3
# Tunisia                       2
# Albania                       2
# Montenegro                    2
# Japan                         2
# US-France                     1
# Name: count, dtype: int64

# %%
# Replicamos la funcion value_counts de una manera distinta
reviews.groupby('points').points.count()
# Out:
# points
# 80       898
# 81      1502
# 82      4041
# 83      6048
# 84     10708
# 85     12411
# 86     15573
# 87     20747
# 88     17871
# 89     12921
# 90     15973
# 91     10536
# 92      9241
# 93      6017
# 94      3462
# 95      1716
# 96       695
# 97       365
# 98       131
# 99        50
# 100       24
# Name: points, dtype: int64

# %%
# Agrupamos los vinos por variedad
reviews_written = reviews.groupby('variety').variety.count()
reviews_written
# Out:
# variety
# Agiorgitiko                120
# Aglianico                  317
# Aidani                       1
# Airen                        6
# Albana                      17
#                           ...
# Zierfandler-Rotgipfler       3
# Zinfandel                 3799
# Zlahtina                     4
# Zweigelt                   219
# Žilavka                      2
# Name: variety, Length: 632, dtype: int64

# %%
# Precio minimo y maximo por variedad de vino
reviews.groupby('variety').price.agg([min, max])
# Out:
#                          min    max
# variety
# Agiorgitiko              8.0   65.0
# Aglianico                6.0  130.0
# Aidani                  27.0   27.0
# Airen                    8.0   10.0
# Albana                   8.0   66.0
# ...                      ...    ...
# Zierfandler-Rotgipfler  20.0   25.0
# Zinfandel                4.0  100.0
# Zlahtina                13.0   17.0
# Zweigelt                 9.0   70.0
# Žilavka                 13.0   15.0
#
# [632 rows x 2 columns]

# %%
# Seleccionar el mejor vino por agrupacion de pais y provncia
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Albania   Mirditë             Albania
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# Australia Australia Other   Australia
#           New South Wales   Australia
# ...                               ...
# Uruguay   Juanico             Uruguay
#           Montevideo          Uruguay
#           Progreso            Uruguay
#           San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Albania   Mirditë           This garnet-colored wine made from 100% Kallme...
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# Australia Australia Other   This big wine presents a sophisticated bouquet...
#           New South Wales   This wine's deep brassy color suggests honey, ...
# ...                                                                       ...
# Uruguay   Juanico           This mature Bordeaux-style blend is earthy on ...
#           Montevideo        Bouza ranks as one of Uruguay's top wineries, ...
#           Progreso          Blackberry and plum aromas come with wood-smok...
#           San Jose          While this ranks as one of the best Uruguayan ...
#           Uruguay           They call it Special Barrel, and one sniff tel...
#
#                                                         designation  points  \
# country   province
# Albania   Mirditë                                               NaN      88
# Argentina Mendoza Province                         Nicasia Vineyard      97
#           Other                                             Reserva      95
# Australia Australia Other                                  Yattarna      92
#           New South Wales                        Noble One Botrytis      93
# ...                                                             ...     ...
# Uruguay   Juanico                  Preludio Barrel Select Lote N 77      90
#           Montevideo        Monte Vide Eu Tannat-Merlot-Tempranillo      90
#           Progreso                                              RPF      89
#           San Jose                 El Preciado Premier Gran Reserva      89
#           Uruguay                                    Special Barrel      89
#
#                             price          province                 region_1  \
# country   province
# Albania   Mirditë            20.0           Mirditë                      NaN
# Argentina Mendoza Province  120.0  Mendoza Province                  Mendoza
#           Other              90.0             Other                    Salta
# Australia Australia Other    65.0   Australia Other  South Eastern Australia
#           New South Wales    32.0   New South Wales          New South Wales
# ...                           ...               ...                      ...
# Uruguay   Juanico            45.0           Juanico                      NaN
#           Montevideo         57.0        Montevideo                      NaN
#           Progreso           23.0          Progreso                      NaN
#           San Jose           60.0          San Jose                      NaN
#           Uruguay            50.0           Uruguay                      NaN
#
#                            region_2     variety                winery
# country   province
# Albania   Mirditë               NaN     Kallmet                Arbëri
# Argentina Mendoza Province      NaN      Malbec  Bodega Catena Zapata
#           Other                 NaN      Malbec                Colomé
# Australia Australia Other       NaN  Chardonnay              Penfolds
#           New South Wales       NaN    Sémillon            De Bortoli
# ...                             ...         ...                   ...
# Uruguay   Juanico               NaN   Red Blend        Familia Deicas
#           Montevideo            NaN   Red Blend                 Bouza
#           Progreso              NaN      Tannat                Pisano
#           San Jose              NaN   Red Blend        Castillo Viejo
#           Uruguay               NaN      Tannat                 Bouza
#
# [455 rows x 10 columns]

# %%
# Agrupamos la designacion de los vinos por grupos
designation_groups = reviews.groupby('designation')
# Generamos un diccionario con todos los grupos
designation_groups.groups
# Out:
# {'"M"': [53140, 105280, 130150], '#50 Mon Chou': [22740], '#SocialSecret': [14104, 53374], ''72': [96960], ''A Naca Rosso': [25093], ''A Rina': [24509], ''Na Vota': [46721], ''Nearly Naked'': [131331], ''S'': [3782, 6861], ''l Clumbé': [59917, 91417, 103054, 127264], '(Benedict Vineyard)': [61712, 147032], '(McLaren Vale-Adelaide Hills)': [143161], '(Southern Highlands) GI': [15104, 146324], '*%#&@!': [18927, 61466, 75597, 116876], '**1 Liter**': [139550], '+7': [38687], '0 Degree Dry': [35796], '0 Degrees': [41141, 93311, 118301], '075 Carati': [9795, 36225, 73719], '1': [78899], '1 C': [67119, 88509, 124719], '1 Lage': [15887, 71357, 145337], '1 Liter': [142546], '1 er Cru Charmes': [63853, 148693], '1 er Cru Les Champs Gains': [63665, 115235, 148595], '1+1=3 U més U fan tres': [147636], '1-liter': [77431], '1/1': [73217], '10 Acre': [38752, 82642, 101980], '10 Anos': [6356, 33926], '10 Anos Collections Tawny': [104951], '10 Anos Tawny': [9265, 25263, 72123], '10 Anos White': [14645, 55085, 58611, 90081, 122901], '10 Vine Age Series': [46
', '20-Years Old Tawny', '20-Years-Old Tawny', '20-year old Tawny', '20-year old tawny', '20/20', '200 Barrels', '200 Monges Reserva', '200 Monges Selección Especial Reserva', '2003 by Bollinger Brut', '202', '20th Anniversary Reserve', '20th Anniversary Vintage', '20th Vintage Sauvignon Blanc', '21st Anniversary Release', '21▪12', '22', '234', '24 Meses en Barrica', '24.4 Brix', '242', '2480', '25 Anni', '25th Anniversary', '25th Anniversary Blanc de Noir', '25th Anniversary J Cuvée', '25th Vintage Rubino Super-Tuscan Style Blend', '26esimo I Brut', '2T', '2V Premium', '2nd Degree', '2nd Degree Medium Sweet', '3 Autores', '3 Brooms', '3 Carati', '3 Castas', '3 Cepas', '3 Clone', '3 Clones', '3 Dijon Clones', '3 Divas', '3 Generaciones', '3 Generations', '3 Girls', '3 Horse Ranch Vineyard', '3 L', '3 Meses en Barrica', '3 Months in Oak', '3 Naissances Terrasses du Larzac', '3 Puttonyos Aszú', '3 Stones Niederhäuser Dry', '3 Trees', '3 Vineyard', '3 de Valandraud', '3&4 Max Cuvée', '30 Anos Tawny', '30 Anos White', '30 Year Old Tawny', '30 Years Old Tawny', '30 Years Tawny', '30 Yr. Imperial Oloroso', '30 Yr. Old Baco Imperial Oloroso', '30-Year Tawny', '30-Year-Old Tawny', '30-Year-Old White', '30-year old tawny', '30-years old Tawny', '3055', '30th Anniversary', '30th Anniversary Cu ...

# %%
# Podemos seleccionar cada grupo
designation_groups.get_group('#50 Mon Chou')
# Out:
#       country                                        description  \
# 22740      US  Marked by enormously ripe, powerful fruit flav...
#
#         designation  points  price    province     region_1 region_2  \
# 22740  #50 Mon Chou      88   55.0  California  Napa Valley     Napa
#
#                         variety          winery
# 22740  Bordeaux-style Red Blend  Jacob Franklin

# %% [markdown]
# ### Datatypes y ausencia de valores

# %%
# Comprobar el tipo de dato de una columna
reviews.points.dtype
# Out:
# dtype('int64')

# %%
# Conversion de tipos
reviews.points.astype(str)
# Out:
# 0         96
# 1         96
# 2         96
# 3         96
# 4         95
#           ..
# 150925    91
# 150926    91
# 150927    91
# 150928    90
# 150929    90
# Name: points, Length: 150930, dtype: object

# %%
# Comprobar cunatos valores null tenemos en una serie
reviews.price.isnull().sum()
# Out:
# 13695

# %%
# Reemplazar valores Null o NaN
reviews.region_1.fillna('Unknown').value_counts().sort_values(ascending=False)
# Out:
# region_1
# Unknown                         25060
# Napa Valley                      6209
# Columbia Valley (WA)             4975
# Mendoza                          3586
# Russian River Valley             3571
#                                 ...
# Vin de Pays de Côtes du Tarn        1
# Clos de Lambrays                    1
# California-Oregon                   1
# Mâcon-Mancey                        1
# Coteaux du Tricastin                1
# Name: count, Length: 1237, dtype: int64

# %% [markdown]
# ### Renombración y combinación

# %%
# Renombracion de columnas
reviews.rename(columns=dict(region_1='region', region_2='locale'))
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province             region             locale  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]

# %%
# Renombrar el indice de indexado
reindexed = reviews.rename_axis('wines', axis='rows')
reindexed
# Out:
#        country                                        description  \
# wines
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# wines
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# wines
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# wines
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]
